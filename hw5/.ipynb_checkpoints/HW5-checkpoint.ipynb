# %%
import pandas as pd
X = pd.read_csv("hw5/q2dset.csv").drop_duplicates()
X
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
import numpy as np
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2).fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0e87d4339117> in <module>
#       1 import numpy as np
#       2 from sklearn.manifold import TSNE
# ----> 3 X_embedded = TSNE(n_components=2).fit_transform(X)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py in fit_transform(self, X, y)
#     889             Embedding of the training data in low-dimensional space.
#     890         """
# --> 891         embedding = self._fit(X)
#     892         self.embedding_ = embedding
#     893         return self.embedding_
#
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py in _fit(self, X, skip_num_points)
#     667             raise ValueError("'angle' must be between 0.0 - 1.0")
#     668         if self.method == 'barnes_hut':
# --> 669             X = self._validate_data(X, accept_sparse=['csr'],
# ...
